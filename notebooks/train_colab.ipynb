# %% [markdown]
# # Atomic Spectrum CNN — Google Colab
# Replace `YOUR_GITHUB_USERNAME` before running. Synthetic data verifies the pipeline only.

# %%
# !git clone https://github.com/YOUR_GITHUB_USERNAME/atomic-spectrum-cnn-copilot.git
# %cd atomic-spectrum-cnn-copilot
# !pip install -r requirements.txt

# %%
# !python scripts/generate_synthetic_data.py --config configs/quickstart.yaml
# !python scripts/train.py --config configs/quickstart.yaml
